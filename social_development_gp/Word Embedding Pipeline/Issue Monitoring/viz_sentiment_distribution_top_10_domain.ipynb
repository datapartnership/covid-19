# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import altair as alt

# %%
df = pd.read_csv("F:/WB/Issue Monitoring/data/sentiment_top_10_urls.csv")
df['sentiment'] = df['sentiment_score'].apply(lambda x: 'positive' if x>=0.2 else 'neutral' if x>=-0.2 else 'negative')

# %%
df
# Out:
#                  root_domain  sentiment_score sentiment
# 0      kupang.tribunnews.com              NaN  negative
# 1        nasional.kompas.com        -0.062500   neutral
# 2            republika.co.id         0.000000   neutral
# 3            republika.co.id         0.200000  positive
# 4            republika.co.id         0.000000   neutral
# ...                      ...              ...       ...
# 1922   kaltim.tribunnews.com        -0.272727  negative
# 1923     nasional.kompas.com         0.000000   neutral
# 1924  nasional.sindonews.com        -0.125000   neutral
# 1925    www.cnnindonesia.com         0.055556   neutral
# 1926  nasional.sindonews.com         0.333333  positive
#
# [1927 rows x 3 columns]

# %%
alt.data_transformers.enable('default', max_rows=None)

alt.Chart(df).mark_bar().encode(
    x = alt.X('root_domain'),
    y = alt.Y('count():Q',stack="normalize", axis=alt.Axis(format='%'), title = '% Sentiment'),
    color = alt.Order('sentiment',sort='descending'),
    order = alt.Order('sentiment',sort='descending')
).properties(
    width=1000,
    height=600,
    title='Sentiment of TOP 10 News Domain Shared in Twitter'
).configure_axis(
    labelFontSize=13,
    titleFontSize=20
).configure_title(
    fontSize=30
).configure_legend(
    labelFontSize=15
).configure_axisX(
    labelAngle = -90
)
# Out:
# alt.Chart(...)
